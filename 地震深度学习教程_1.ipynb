# %% [markdown]
# <a href="https://colab.research.google.com/github/gostopy/KAIR/blob/master/%E5%9C%B0%E9%9C%87%E6%B7%B1%E5%BA%A6%E5%AD%A6%E4%B9%A0%E6%95%99%E7%A8%8B_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 使用深度卷积神经网络在二维地震图像中映射盐分
# 本教程介绍了如何使用深度卷积神经网络在二维地震图像中映射盐分。 要学习本教程，您不需要任何特殊的硬件、软件、数据或经验——只需一个 Google 帐户。# Mapping salt in 2-D seismic image using a deep convolutional neural network
# This tutorial describes how to map salt in a 2-D seismic image using a deep convolutional neural network. To follow this tutorial, you won't need any special hardware, software, data or experience - just a Google account.

# %% [markdown]
# ## Setup ##

# %% [markdown]
# 1. First, you will need sign in to your Google account. If you're not signed in, you can sign in [here](https://myaccount.google.com/?utm_source=sign_in_no_continue)
# 2. Next, head on to the [Colab Welcome Page](https://colab.research.google.com/notebooks/welcome.ipynb#recent=true).
# 3. There, select Github in the top tab and search for https://github.com/thilowrona/seismic_deep_learning/blob/master/tutorial-1/tutorial-1.ipynb
# 4. Clicking opens this notebook. This is a Jupyter notebook; an awesome combination of code and documentation allowing us work on, describe and share our projects.
# 5. Before running anything in here, you need to tell Colab that would like to use a GPU (important to train our models quickly). This is done by clicking on the ‘Runtime’ tab, selecting ‘Change runtime type’, changing hardware accelerator to ´GPU´ and clicking ´save´. Excellent! Colab is now set up!
# 6. When you run the first cell, you will face a pop-up saying ‘Warning: This notebook was not authored by Google’; you should click on ‘Run Anyway’ to get rid of the warning.
# 7. Next we want to save our notebook. If you click on ‘File’ and then ‘Save’, you will see a pop-up saying ´CANNOT SAVE CHANGES´. Now, click on ‘SAVE A COPY IN DRIVE’. This opens up a new tab with the same file, but this time located in your Drive. If you want to continue working after saving, use the file in the new tab. Your notebook will be saved in a folder called Colab Notebooks in your Google Drive by default.

# %% [markdown]
# ## Pre-processing ##
# Now that everything is set up, we want to load our data, but first we need to load a couple of useful python packages:

# %%
from sys import stdout

import random
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout

from sklearn.metrics import confusion_matrix

# %% [markdown]
# Next we clone the Github repository to get our data:

# %%
# !git clone https://github.com/thilowrona/seismic_deep_learning
# Out:
# Cloning into 'seismic_deep_learning'...
# remote: Enumerating objects: 798, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 798 (delta 21), reused 9 (delta 2), pack-reused 750
# Receiving objects: 100% (798/798), 46.46 MiB | 26.83 MiB/s, done.
# Resolving deltas: 100% (388/388), done.

# %% [markdown]
# Now you can load and plot the seismic image and its mask:

# %%
data = mpimg.imread('seismic_deep_learning/tutorial-1/seismic.tif')
data = data[:,:,:1]/255

mask = mpimg.imread('seismic_deep_learning/tutorial-1/mask.tif').copy()
mask = (mask-mask.min())/(mask.max()-mask.min())

plt.matshow(data[:,:,0], interpolation='spline16', cmap=plt.cm.gray, aspect=1)
plt.matshow(mask, interpolation='spline16', aspect=1)

# %% [markdown]
# So now we have one image with a mask, but we need many more examples to train a deep learning model. Of course, we could label more examples, but that takes time and additional data. Let's say we have neither of those. In this case, we can split up our image and mask in to many pairs of small patches. So let's do that:

# %%
number_train = 5000                             # Number of training examples
number_val   = 1000                             # Number of validation examples
dim          = (64,64,1)                        # Size of examples


def patchify(data, mask, patch_num, dim):

  X = np.empty((patch_num, *dim))
  y = np.empty((patch_num,2))

  (t_max, x_max, _) = data.shape

  for n in range(patch_num):
      
      # Select random point in data (not at the edge)   
      x_n = random.randint(dim[1]//2,x_max-dim[1]//2)
      t_n = random.randint(dim[0]//2,t_max-dim[0]//2)
      
      # Extract data patch around point   
      X[n,:,:,0] = data[t_n-dim[0]//2:t_n+dim[0]//2,x_n-dim[1]//2:x_n+dim[1]//2,0]
      
      # Note label of point (one-hot-encoding)   
      y[n,0] = mask[t_n,x_n]
      y[n,1] = 1 - mask[t_n,x_n]

  return X, y



X_train, y_train = patchify(data[:,:1200], mask[:,:1200], number_train, dim)
X_val,   y_val   = patchify(data[:,1200:], mask[:,1200:], number_val, dim)

# %% [markdown]
# Before training, it's always a good idea to look at the training data, so let's do that:

# %%
fig, axs = plt.subplots(5, 5, figsize=(15,15))

k = 0
for n in range(5):
  for m in range(5):
    axs[n,m].imshow(X_train[k,:,:,0], interpolation='spline16', cmap=plt.cm.gray, aspect=1)
    axs[n,m].set_xticks([])
    axs[n,m].set_yticks([])
    k += 1
    if y_train[k,0] == 1:
      axs[n,m].set_title('salt')
    else:
      axs[n,m].set_title('No salt')

# %% [markdown]
# What do you notice?
#
# *   Is it an easy task?
# *   Could you predict the labels?
#
# Let's see if it will work...

# %% [markdown]
# ## Training ##
# To train our first model, we need to define its architecture. A typical deep convolution neural network for image classification would look something like this:

# %%
model = Sequential([Conv2D(16, 3, padding='same', activation='relu', input_shape=dim),
                    MaxPooling2D(),
                    Dropout(0.2),
                    Conv2D(32, 3, padding='same', activation='relu'),
                    MaxPooling2D(),
                    Dropout(0.2),
                    Conv2D(64, 3, padding='same', activation='relu'),
                    MaxPooling2D(),
                    Dropout(0.2),
                    Flatten(),
                    Dense(512, activation='relu'),
                    Dense(2, activation='softmax')])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['binary_accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 16)       0
#  )
#
#  dropout (Dropout)           (None, 32, 32, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 2,121,986
# Trainable params: 2,121,986
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now you can train your first convolutional neural net:

# %%
history = model.fit(X_train, 
                    y_train, 
                    validation_data=(X_val, y_val), 
                    epochs=100)
# Out:
# Epoch 1/100
# 157/157 [==============================] - 13s 19ms/step - loss: 0.2805 - binary_accuracy: 0.9162 - val_loss: 0.2624 - val_binary_accuracy: 0.9010
# Epoch 2/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.1943 - binary_accuracy: 0.9328 - val_loss: 0.2180 - val_binary_accuracy: 0.9260
# Epoch 3/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.1507 - binary_accuracy: 0.9420 - val_loss: 0.1804 - val_binary_accuracy: 0.9390
# Epoch 4/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.1219 - binary_accuracy: 0.9560 - val_loss: 0.1844 - val_binary_accuracy: 0.9450
# Epoch 5/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.1159 - binary_accuracy: 0.9586 - val_loss: 0.2198 - val_binary_accuracy: 0.9260
# Epoch 6/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0916 - binary_accuracy: 0.9666 - val_loss: 0.2403 - val_binary_accuracy: 0.9180
# Epoch 7/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0826 - binary_accuracy: 0.9678 - val_loss: 0.2139 - val_binary_accuracy: 0.9460
# Epoch 8/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0709 - binary_accuracy: 0.9730 - val_loss: 0.2172 - val_binary_accuracy: 0.9360
# Epoch 9/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0681 - binary_accuracy: 0.9736 - val_loss: 0.2012 - val_binary_accuracy: 0.9490
# Epoch 10/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0526 - binary_accuracy: 0.9798 - val_loss: 0.2044 - val_binary_accuracy: 0.9580
# Epoch 11/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0435 - binary_accuracy: 0.9848 - val_loss: 0.2298 - val_binary_accuracy: 0.9480
# Epoch 12/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0422 - binary_accuracy: 0.9844 - val_loss: 0.2138 - val_binary_accuracy: 0.9530
# Epoch 13/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0383 - binary_accuracy: 0.9852 - val_loss: 0.2829 - val_binary_accuracy: 0.9230
# Epoch 14/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0332 - binary_accuracy: 0.9858 - val_loss: 0.2966 - val_binary_accuracy: 0.9240
# Epoch 15/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0250 - binary_accuracy: 0.9904 - val_loss: 0.3252 - val_binary_accuracy: 0.9300
# Epoch 16/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0214 - binary_accuracy: 0.9906 - val_loss: 0.2989 - val_binary_accuracy: 0.9440
# Epoch 17/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0293 - binary_accuracy: 0.9888 - val_loss: 0.3363 - val_binary_accuracy: 0.9330
# Epoch 18/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0285 - binary_accuracy: 0.9872 - val_loss: 0.3073 - val_binary_accuracy: 0.9430
# Epoch 19/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0159 - binary_accuracy: 0.9936 - val_loss: 0.3570 - val_binary_accuracy: 0.9520
# Epoch 20/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0205 - binary_accuracy: 0.9914 - val_loss: 0.3767 - val_binary_accuracy: 0.9170
# Epoch 21/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0139 - binary_accuracy: 0.9934 - val_loss: 0.3588 - val_binary_accuracy: 0.9420
# Epoch 22/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0114 - binary_accuracy: 0.9950 - val_loss: 0.3384 - val_binary_accuracy: 0.9570
# Epoch 23/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0077 - binary_accuracy: 0.9958 - val_loss: 0.3840 - val_binary_accuracy: 0.9540
# Epoch 24/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0201 - binary_accuracy: 0.9916 - val_loss: 0.3290 - val_binary_accuracy: 0.9470
# Epoch 25/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0117 - binary_accuracy: 0.9948 - val_loss: 0.3929 - val_binary_accuracy: 0.9330
# Epoch 26/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0136 - binary_accuracy: 0.9942 - val_loss: 0.3644 - val_binary_accuracy: 0.9410
# Epoch 27/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0121 - binary_accuracy: 0.9944 - val_loss: 0.3641 - val_binary_accuracy: 0.9510
# Epoch 28/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0168 - binary_accuracy: 0.9916 - val_loss: 0.4386 - val_binary_accuracy: 0.9310
# Epoch 29/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0158 - binary_accuracy: 0.9936 - val_loss: 0.3611 - val_binary_accuracy: 0.9460
# Epoch 30/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0061 - binary_accuracy: 0.9964 - val_loss: 0.4462 - val_binary_accuracy: 0.9510
# Epoch 31/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0179 - binary_accuracy: 0.9932 - val_loss: 0.3582 - val_binary_accuracy: 0.9540
# Epoch 32/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0112 - binary_accuracy: 0.9946 - val_loss: 0.3595 - val_binary_accuracy: 0.9410
# Epoch 33/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0087 - binary_accuracy: 0.9956 - val_loss: 0.3627 - val_binary_accuracy: 0.9400
# Epoch 34/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0107 - binary_accuracy: 0.9946 - val_loss: 0.3804 - val_binary_accuracy: 0.9480
# Epoch 35/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0095 - binary_accuracy: 0.9956 - val_loss: 0.4516 - val_binary_accuracy: 0.9460
# Epoch 36/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0088 - binary_accuracy: 0.9950 - val_loss: 0.3951 - val_binary_accuracy: 0.9540
# Epoch 37/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0064 - binary_accuracy: 0.9964 - val_loss: 0.4218 - val_binary_accuracy: 0.9510
# Epoch 38/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0132 - binary_accuracy: 0.9942 - val_loss: 0.3594 - val_binary_accuracy: 0.9530
# Epoch 39/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0057 - binary_accuracy: 0.9966 - val_loss: 0.4136 - val_binary_accuracy: 0.9480
# Epoch 40/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0041 - binary_accuracy: 0.9966 - val_loss: 0.4182 - val_binary_accuracy: 0.9570
# Epoch 41/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0045 - binary_accuracy: 0.9966 - val_loss: 0.5721 - val_binary_accuracy: 0.9240
# Epoch 42/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0077 - binary_accuracy: 0.9960 - val_loss: 0.6192 - val_binary_accuracy: 0.9250
# Epoch 43/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0273 - binary_accuracy: 0.9890 - val_loss: 0.3621 - val_binary_accuracy: 0.9360
# Epoch 44/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0077 - binary_accuracy: 0.9954 - val_loss: 0.4548 - val_binary_accuracy: 0.9570
# Epoch 45/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0058 - binary_accuracy: 0.9960 - val_loss: 0.4698 - val_binary_accuracy: 0.9580
# Epoch 46/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0170 - binary_accuracy: 0.9934 - val_loss: 0.3371 - val_binary_accuracy: 0.9500
# Epoch 47/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0049 - binary_accuracy: 0.9966 - val_loss: 0.3919 - val_binary_accuracy: 0.9500
# Epoch 48/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0051 - binary_accuracy: 0.9962 - val_loss: 0.4390 - val_binary_accuracy: 0.9530
# Epoch 49/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0045 - binary_accuracy: 0.9964 - val_loss: 0.4610 - val_binary_accuracy: 0.9540
# Epoch 50/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0038 - binary_accuracy: 0.9970 - val_loss: 0.4681 - val_binary_accuracy: 0.9570
# Epoch 51/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0030 - binary_accuracy: 0.9970 - val_loss: 0.4673 - val_binary_accuracy: 0.9550
# Epoch 52/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0131 - binary_accuracy: 0.9940 - val_loss: 0.4816 - val_binary_accuracy: 0.9460
# Epoch 53/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0113 - binary_accuracy: 0.9940 - val_loss: 0.4147 - val_binary_accuracy: 0.9520
# Epoch 54/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0156 - binary_accuracy: 0.9924 - val_loss: 0.4432 - val_binary_accuracy: 0.9530
# Epoch 55/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0047 - binary_accuracy: 0.9966 - val_loss: 0.4240 - val_binary_accuracy: 0.9570
# Epoch 56/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0056 - binary_accuracy: 0.9962 - val_loss: 0.5166 - val_binary_accuracy: 0.9520
# Epoch 57/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0031 - binary_accuracy: 0.9970 - val_loss: 0.4793 - val_binary_accuracy: 0.9530
# Epoch 58/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0024 - binary_accuracy: 0.9970 - val_loss: 0.4823 - val_binary_accuracy: 0.9540
# Epoch 59/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0031 - binary_accuracy: 0.9970 - val_loss: 0.5034 - val_binary_accuracy: 0.9540
# Epoch 60/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0029 - binary_accuracy: 0.9970 - val_loss: 0.5400 - val_binary_accuracy: 0.9530
# Epoch 61/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0071 - binary_accuracy: 0.9950 - val_loss: 0.5074 - val_binary_accuracy: 0.9340
# Epoch 62/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0247 - binary_accuracy: 0.9924 - val_loss: 0.4758 - val_binary_accuracy: 0.9450
# Epoch 63/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0040 - binary_accuracy: 0.9966 - val_loss: 0.4799 - val_binary_accuracy: 0.9540
# Epoch 64/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0028 - binary_accuracy: 0.9968 - val_loss: 0.5243 - val_binary_accuracy: 0.9580
# Epoch 65/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0039 - binary_accuracy: 0.9968 - val_loss: 0.4917 - val_binary_accuracy: 0.9550
# Epoch 66/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0047 - binary_accuracy: 0.9966 - val_loss: 0.5276 - val_binary_accuracy: 0.9510
# Epoch 67/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0033 - binary_accuracy: 0.9970 - val_loss: 0.5164 - val_binary_accuracy: 0.9520
# Epoch 68/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0169 - binary_accuracy: 0.9920 - val_loss: 0.4478 - val_binary_accuracy: 0.9410
# Epoch 69/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0085 - binary_accuracy: 0.9954 - val_loss: 0.4667 - val_binary_accuracy: 0.9560
# Epoch 70/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0050 - binary_accuracy: 0.9968 - val_loss: 0.5554 - val_binary_accuracy: 0.9560
# Epoch 71/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0174 - binary_accuracy: 0.9922 - val_loss: 0.4592 - val_binary_accuracy: 0.9500
# Epoch 72/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0045 - binary_accuracy: 0.9968 - val_loss: 0.4446 - val_binary_accuracy: 0.9440
# Epoch 73/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0066 - binary_accuracy: 0.9960 - val_loss: 0.4717 - val_binary_accuracy: 0.9520
# Epoch 74/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0053 - binary_accuracy: 0.9960 - val_loss: 0.4875 - val_binary_accuracy: 0.9550
# Epoch 75/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0040 - binary_accuracy: 0.9968 - val_loss: 0.4725 - val_binary_accuracy: 0.9600
# Epoch 76/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0131 - binary_accuracy: 0.9928 - val_loss: 0.5699 - val_binary_accuracy: 0.9480
# Epoch 77/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0057 - binary_accuracy: 0.9958 - val_loss: 0.4532 - val_binary_accuracy: 0.9560
# Epoch 78/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0046 - binary_accuracy: 0.9968 - val_loss: 0.4541 - val_binary_accuracy: 0.9590
# Epoch 79/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0046 - binary_accuracy: 0.9966 - val_loss: 0.4440 - val_binary_accuracy: 0.9580
# Epoch 80/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0033 - binary_accuracy: 0.9968 - val_loss: 0.4938 - val_binary_accuracy: 0.9610
# Epoch 81/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0031 - binary_accuracy: 0.9970 - val_loss: 0.4967 - val_binary_accuracy: 0.9540
# Epoch 82/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0028 - binary_accuracy: 0.9970 - val_loss: 0.4861 - val_binary_accuracy: 0.9540
# Epoch 83/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0023 - binary_accuracy: 0.9970 - val_loss: 0.4787 - val_binary_accuracy: 0.9570
# Epoch 84/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0031 - binary_accuracy: 0.9970 - val_loss: 0.5196 - val_binary_accuracy: 0.9570
# Epoch 85/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0028 - binary_accuracy: 0.9970 - val_loss: 0.4588 - val_binary_accuracy: 0.9600
# Epoch 86/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0026 - binary_accuracy: 0.9970 - val_loss: 0.4661 - val_binary_accuracy: 0.9570
# Epoch 87/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0114 - binary_accuracy: 0.9942 - val_loss: 0.6239 - val_binary_accuracy: 0.9500
# Epoch 88/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0253 - binary_accuracy: 0.9916 - val_loss: 0.4557 - val_binary_accuracy: 0.9360
# Epoch 89/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0079 - binary_accuracy: 0.9956 - val_loss: 0.5080 - val_binary_accuracy: 0.9360
# Epoch 90/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0035 - binary_accuracy: 0.9968 - val_loss: 0.5673 - val_binary_accuracy: 0.9460
# Epoch 91/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0044 - binary_accuracy: 0.9966 - val_loss: 0.4892 - val_binary_accuracy: 0.9510
# Epoch 92/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0028 - binary_accuracy: 0.9970 - val_loss: 0.5047 - val_binary_accuracy: 0.9470
# Epoch 93/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0026 - binary_accuracy: 0.9970 - val_loss: 0.5255 - val_binary_accuracy: 0.9480
# Epoch 94/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0031 - binary_accuracy: 0.9966 - val_loss: 0.5323 - val_binary_accuracy: 0.9540
# Epoch 95/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0030 - binary_accuracy: 0.9966 - val_loss: 0.4929 - val_binary_accuracy: 0.9530
# Epoch 96/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0026 - binary_accuracy: 0.9970 - val_loss: 0.5034 - val_binary_accuracy: 0.9560
# Epoch 97/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0064 - binary_accuracy: 0.9954 - val_loss: 0.5424 - val_binary_accuracy: 0.9510
# Epoch 98/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0045 - binary_accuracy: 0.9966 - val_loss: 0.6126 - val_binary_accuracy: 0.9500
# Epoch 99/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0045 - binary_accuracy: 0.9962 - val_loss: 0.5441 - val_binary_accuracy: 0.9510
# Epoch 100/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0032 - binary_accuracy: 0.9966 - val_loss: 0.5653 - val_binary_accuracy: 0.9500

# %% [markdown]
# To visualize our training, you can plot learning curves:

# %%
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# and a confusion matrix:

# %%
def plot_confusion_matrix(cm, names, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(names))
    plt.xticks(tick_marks, names, rotation=45)
    plt.yticks(tick_marks, names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    fmt = 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                    ha="center", va='center',
                    color="white" if cm[i, j] > thresh else "black")



y_true = y_val
y_pred = model.predict(X_val)

cm = confusion_matrix(y_true.astype(int)[:,0], y_pred.astype(int)[:,0]) + np.fliplr(confusion_matrix(y_true.astype(int)[:,1], y_pred.astype(int)[:,1]))
   
plot_confusion_matrix(cm, ['No salt', 'Salt'])

# %% [markdown]
# ##Application##
# Finally, we can apply our model to the entire image to see how well it has learned to recognize salt structures in our seismic image. Because we have to predict the label of each pixel in the image, this takes a while (~4 mins)

# %%
(t_max, x_max, _) = data.shape
result            = np.zeros((t_max,x_max,2))
batch             = np.zeros((t_max-dim[1], *dim))

m = 0
n = 0
for x in range(dim[0]//2,x_max-dim[0]//2): 
  stdout.write("\r%d" % m)
  stdout.flush()
  m = m + 100/(x_max-dim[0])

  for t in range(dim[1]//2,t_max-dim[1]//2):
    batch[n,:,:,0] = data[t-dim[1]//2:t+dim[1]//2, x-dim[0]//2:x+dim[0]//2, 0] 
    n = n + 1

  result[dim[1]//2:t_max-dim[1]//2,x,:] = model.predict_on_batch(batch)
  n = 0

plt.matshow(data[:,:,0], interpolation='spline16', cmap=plt.cm.gray, aspect=1)
plt.matshow(mask, interpolation='spline16', aspect=1)
plt.matshow(result[:,:,0], interpolation='spline16', aspect=1)
plt.show()
# Out:
# 99

# %% [markdown]
# Excellent! Your first model is already able to recognize most of the salt in the seismic section. If you want to know how to improve the prediction in terms of speed and accuracy, check out [tutorial-2](https://github.com/thilowrona/seismic_deep_learning/blob/master/tutorial-2/tutorial_2.ipynb)
